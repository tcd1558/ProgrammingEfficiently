# %% [markdown]
# ## 05_06: Inverted index challenge

# %%
print(open('sonnets/XVIII.txt', 'r').read())
# Out:
# Shall I compare thee to a summer's day?
# Thou art more lovely and more temperate:
# Rough winds do shake the darling buds of May,
# And summer's lease hath all too short a date:
# Sometime too hot the eye of heaven shines,
# And often is his gold complexion dimm'd;
# And every fair from fair sometime declines,
# By chance or nature's changing course untrimm'd;
# But thy eternal summer shall not fade
# Nor lose possession of that fair thou owest;
# Nor shall Death brag thou wander'st in his shade,
# When in eternal lines to time thou growest:
#   So long as men can breathe or eyes can see,
#   So long lives this and this gives life to thee.

# %%
exclude = set('!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~')

def words(line):
    # remove punctuation
    clean = ''.join(char for char in line if char not in exclude)

    # split the line into words, make all words lowercase, return list 
    return [word.lower() for word in clean.split()]

def indexfile(filename):
    ret = []

    # enumerate lines in file
    for i, line in enumerate(open(filename, 'r').readlines()):
        # for each word in line...
        for word in words(line):
            # ...append a line to results, listing word and location
            ret.append(f'{word} {filename},{i}')
    
    return '\n'.join(ret)

# %%
print(indexfile('sonnets/XVIII.txt'))
# Out:
# shall sonnets/XVIII.txt,0
# i sonnets/XVIII.txt,0
# compare sonnets/XVIII.txt,0
# thee sonnets/XVIII.txt,0
# to sonnets/XVIII.txt,0
# a sonnets/XVIII.txt,0
# summers sonnets/XVIII.txt,0
# day sonnets/XVIII.txt,0
# thou sonnets/XVIII.txt,1
# art sonnets/XVIII.txt,1
# more sonnets/XVIII.txt,1
# lovely sonnets/XVIII.txt,1
# and sonnets/XVIII.txt,1
# more sonnets/XVIII.txt,1
# temperate sonnets/XVIII.txt,1
# rough sonnets/XVIII.txt,2
# winds sonnets/XVIII.txt,2
# do sonnets/XVIII.txt,2
# shake sonnets/XVIII.txt,2
# the sonnets/XVIII.txt,2
# darling sonnets/XVIII.txt,2
# buds sonnets/XVIII.txt,2
# of sonnets/XVIII.txt,2
# may sonnets/XVIII.txt,2
# and sonnets/XVIII.txt,3
# summers sonnets/XVIII.txt,3
# lease sonnets/XVIII.txt,3
# hath sonnets/XVIII.txt,3
# all sonnets/XVIII.txt,3
# too sonnets/XVIII.txt,3
# short sonnets/XVIII.txt,3
# a sonnets/XVIII.txt,3
# date sonnets/XVIII.txt,3
# sometime sonnets/XVIII.txt,4
# too sonnets/XVIII.txt,4
# hot sonnets/XVIII.txt,4
# the sonnets/XVIII.txt,4
# eye sonnets/XVIII.txt,4
# of sonnets/XVIII.txt,4
# heaven sonnets/XVIII.txt,4
# shines sonnets/XVIII.txt,4
# and sonnets/XVIII.txt,5
# often sonnets/XVIII.txt,5
# is sonnets/XVIII.txt,5
# his sonnets/XVIII.txt,5
# gold sonnets/XVIII.txt,5
# complexion sonnets/XVIII.txt,5
# dimmd sonnets/XVIII.txt,5
# and sonnets/XVIII.txt,6
# every sonnets/XVIII.txt,6
# fair sonnets/XVIII.txt,6
# from sonnets/XVIII.txt,6
# fair sonnets/XVIII.txt,6
# sometime sonnets/XVIII.txt,6
# declines sonnets/XVIII.txt,6
# by sonnets/XVIII.txt,7
# chance sonnets/XVIII.txt,7
# or sonnets/XVIII.txt,7
# natures sonnets/XVIII.txt,7
# changing sonnets/XVIII.txt,7
# course sonnets/XVIII.txt,7
# untrimmd sonnets/XVIII.txt,7
# but sonnets/XVIII.txt,8
# thy sonnets/XVIII.txt,8
# eternal sonnets/XVIII.txt,8
# summer sonnets/XVIII.txt,8
# shall sonnets/XVIII.txt,8
# not sonnets/XVIII.txt,8
# fade sonnets/XVIII.txt,8
# nor sonnets/XVIII.txt,9
# lose sonnets/XVIII.txt,9
# possession sonnets/XVIII.txt,9
# of sonnets/XVIII.txt,9
# that sonnets/XVIII.txt,9
# fair sonnets/XVIII.txt,9
# thou sonnets/XVIII.txt,9
# owest sonnets/XVIII.txt,9
# nor sonnets/XVIII.txt,10
# shall sonnets/XVIII.txt,10
# death sonnets/XVIII.txt,10
# brag sonnets/XVIII.txt,10
# thou sonnets/XVIII.txt,10
# wanderst sonnets/XVIII.txt,10
# in sonnets/XVIII.txt,10
# his sonnets/XVIII.txt,10
# shade sonnets/XVIII.txt,10
# when sonnets/XVIII.txt,11
# in sonnets/XVIII.txt,11
# eternal sonnets/XVIII.txt,11
# lines sonnets/XVIII.txt,11
# to sonnets/XVIII.txt,11
# time sonnets/XVIII.txt,11
# thou sonnets/XVIII.txt,11
# growest sonnets/XVIII.txt,11
# so sonnets/XVIII.txt,12
# long sonnets/XVIII.txt,12
# as sonnets/XVIII.txt,12
# men sonnets/XVIII.txt,12
# can sonnets/XVIII.txt,12
# breathe sonnets/XVIII.txt,12
# or sonnets/XVIII.txt,12
# eyes sonnets/XVIII.txt,12
# can sonnets/XVIII.txt,12
# see sonnets/XVIII.txt,12
# so sonnets/XVIII.txt,13
# long sonnets/XVIII.txt,13
# lives sonnets/XVIII.txt,13
# this sonnets/XVIII.txt,13
# and sonnets/XVIII.txt,13
# this sonnets/XVIII.txt,13
# gives sonnets/XVIII.txt,13
# life sonnets/XVIII.txt,13
# to sonnets/XVIII.txt,13
# thee sonnets/XVIII.txt,13

# %%
import glob

# %%
glob.glob('sonnets/*.txt')
# Out:
# ['sonnets/CXXXV.txt',
#  'sonnets/CXLVII.txt',
#  'sonnets/CXVIII.txt',
#  'sonnets/XLIII.txt',
#  'sonnets/LXXVIII.txt',
#  'sonnets/XIII.txt',
#  'sonnets/IX.txt',
#  'sonnets/LXVII.txt',
#  'sonnets/CLIV.txt',
#  'sonnets/XXIII.txt',
#  'sonnets/XCV.txt',
#  'sonnets/CXXVII.txt',
#  'sonnets/LXXXVII.txt',
#  'sonnets/LIII.txt',
#  'sonnets/LVIII.txt',
#  'sonnets/LXXXIX.txt',
#  'sonnets/LIX.txt',
#  'sonnets/XCIV.txt',
#  'sonnets/CXXVI.txt',
#  'sonnets/XXIV.txt',
#  'sonnets/CXLV.txt',
#  'sonnets/CXI.txt',
#  'sonnets/XXI.txt',
#  'sonnets/LXIV.txt',
#  'sonnets/XXXIV.txt',
#  'sonnets/CXXV.txt',
#  'sonnets/XLI.txt',
#  'sonnets/CXXXIV.txt',
#  'sonnets/CXL.txt',
#  'sonnets/XLVI.txt',
#  'sonnets/II.txt',
#  'sonnets/CXLIV.txt',
#  'sonnets/CLI.txt',
#  'sonnets/LXXIV.txt',
#  'sonnets/LXXXII.txt',
#  'sonnets/LII.txt',
#  'sonnets/XXVII.txt',
#  'sonnets/CXVI.txt',
#  'sonnets/CXXIII.txt',
#  'sonnets/LXXXIII.txt',
#  'sonnets/CXX.txt',
#  'sonnets/VIII.txt',
#  'sonnets/LVII.txt',
#  'sonnets/LXXXVIII.txt',
#  'sonnets/XXX.txt',
#  'sonnets/XVIII.txt',
#  'sonnets/CXLIII.txt',
#  'sonnets/XLVII.txt',
#  'sonnets/XVII.txt',
#  'sonnets/LXIII.txt',
#  'sonnets/CX.txt',
#  'sonnets/LXXI.txt',
#  'sonnets/XLIX.txt',
#  'sonnets/CIV.txt',
#  'sonnets/LV.txt',
#  'sonnets/XIV.txt',
#  'sonnets/XXXVIII.txt',
#  'sonnets/XXXI.txt',
#  'sonnets/CL.txt',
#  'sonnets/I.txt',
#  'sonnets/CXIX.txt',
#  'sonnets/CXXII.txt',
#  'sonnets/III.txt',
#  'sonnets/LXXXVI.txt',
#  'sonnets/L.txt',
#  'sonnets/LXXX.txt',
#  'sonnets/CI.txt',
#  'sonnets/XCVIII.txt',
#  'sonnets/VII.txt',
#  'sonnets/XC.txt',
#  'sonnets/VI.txt',
#  'sonnets/XLII.txt',
#  'sonnets/CXXXVIII.txt',
#  'sonnets/LXV.txt',
#  'sonnets/X.txt',
#  'sonnets/LXXXI.txt',
#  'sonnets/XV.txt',
#  'sonnets/CXXIX.txt',
#  'sonnets/CXII.txt',
#  'sonnets/LVI.txt',
#  'sonnets/XXXV.txt',
#  'sonnets/LXX.txt',
#  'sonnets/C.txt',
#  'sonnets/XII.txt',
#  'sonnets/LI.txt',
#  'sonnets/CXIII.txt',
#  'sonnets/XL.txt',
#  'sonnets/CII.txt',
#  'sonnets/LXXV.txt',
#  'sonnets/CLIII.txt',
#  'sonnets/XCVII.txt',
#  'sonnets/XXVI.txt',
#  'sonnets/XCVI.txt',
#  'sonnets/CXXIV.txt',
#  'sonnets/CXXXVII.txt',
#  'sonnets/XX.txt',
#  'sonnets/LXVI.txt',
#  'sonnets/V.txt',
#  'sonnets/CXXVIII.txt',
#  'sonnets/XXXVI.txt',
#  'sonnets/CVII.txt',
#  'sonnets/LXI.txt',
#  'sonnets/XIX.txt',
#  'sonnets/CIII.txt',
#  'sonnets/LX.txt',
#  'sonnets/CXLVI.txt',
#  'sonnets/CXXXVI.txt',
#  'sonnets/CIX.txt',
#  'sonnets/XLIV.txt',
#  'sonnets/XCIII.txt',
#  'sonnets/CV.txt',
#  'sonnets/LXXVI.txt',
#  'sonnets/CXXXIII.txt',
#  'sonnets/CXLVIII.txt',
#  'sonnets/CXIV.txt',
#  'sonnets/CVIII.txt',
#  'sonnets/XI.txt',
#  'sonnets/LXXXV.txt',
#  'sonnets/CXVII.txt',
#  'sonnets/XCI.txt',
#  'sonnets/LXVIII.txt',
#  'sonnets/LXXIX.txt',
#  'sonnets/CXLIX.txt',
#  'sonnets/CLII.txt',
#  'sonnets/XVI.txt',
#  'sonnets/CVI.txt',
#  'sonnets/CXXXIX.txt',
#  'sonnets/LXXVII.txt',
#  'sonnets/CXXX.txt',
#  'sonnets/CXXXI.txt',
#  'sonnets/XXXII.txt',
#  'sonnets/LXII.txt',
#  'sonnets/XXV.txt',
#  'sonnets/XXXIII.txt',
#  'sonnets/CXV.txt',
#  'sonnets/CXLI.txt',
#  'sonnets/XXII.txt',
#  'sonnets/XCII.txt',
#  'sonnets/XLVIII.txt',
#  'sonnets/LXXXIV.txt',
#  'sonnets/XXXVII.txt',
#  'sonnets/LXXII.txt',
#  'sonnets/CXLII.txt',
#  'sonnets/XXVIII.txt',
#  'sonnets/IV.txt',
#  'sonnets/XLV.txt',
#  'sonnets/CXXXII.txt',
#  'sonnets/CXXI.txt',
#  'sonnets/XXXIX.txt',
#  'sonnets/LXXIII.txt',
#  'sonnets/LXIX.txt',
#  'sonnets/XXIX.txt',
#  'sonnets/XCIX.txt',
#  'sonnets/LIV.txt']
