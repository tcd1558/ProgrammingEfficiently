# %% [markdown]
# ## 05_07: Inverted index solution

# %%
import multiprocessing
import glob
import collections

# %%
# %%file index.py

exclude = set('!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~')

def words(line):
    # remove punctuation
    clean = ''.join(char for char in line if char not in exclude)

    # split the line into words, make all words lowercase, return list 
    return [word.lower() for word in clean.split()]

def indexfile(filename):
    ret = []

    # enumerate lines in file
    for i, line in enumerate(open(filename, 'r').readlines()):
        # for each word in line...
        for word in words(line):
            # ...append a line to results, listing word and location
            ret.append(f'{word} {filename},{i}')
    
    return '\n'.join(ret)
# Out:
# Writing index.py

# %%
import index

# %%
pool = multiprocessing.Pool(processes=4)
partials = pool.map(index.indexfile, glob.glob('sonnets/*.txt'))
pool.close()

# %%
len(partials)
# Out:
# 154

# %%
print(partials[0])
# Out:
# whoever sonnets/CXXXV.txt,0
# hath sonnets/CXXXV.txt,0
# her sonnets/CXXXV.txt,0
# wish sonnets/CXXXV.txt,0
# thou sonnets/CXXXV.txt,0
# hast sonnets/CXXXV.txt,0
# thy sonnets/CXXXV.txt,0
# will sonnets/CXXXV.txt,0
# and sonnets/CXXXV.txt,1
# will sonnets/CXXXV.txt,1
# to sonnets/CXXXV.txt,1
# boot sonnets/CXXXV.txt,1
# and sonnets/CXXXV.txt,1
# will sonnets/CXXXV.txt,1
# in sonnets/CXXXV.txt,1
# overplus sonnets/CXXXV.txt,1
# more sonnets/CXXXV.txt,2
# than sonnets/CXXXV.txt,2
# enough sonnets/CXXXV.txt,2
# am sonnets/CXXXV.txt,2
# i sonnets/CXXXV.txt,2
# that sonnets/CXXXV.txt,2
# vex sonnets/CXXXV.txt,2
# thee sonnets/CXXXV.txt,2
# still sonnets/CXXXV.txt,2
# to sonnets/CXXXV.txt,3
# thy sonnets/CXXXV.txt,3
# sweet sonnets/CXXXV.txt,3
# will sonnets/CXXXV.txt,3
# making sonnets/CXXXV.txt,3
# addition sonnets/CXXXV.txt,3
# thus sonnets/CXXXV.txt,3
# wilt sonnets/CXXXV.txt,4
# thou sonnets/CXXXV.txt,4
# whose sonnets/CXXXV.txt,4
# will sonnets/CXXXV.txt,4
# is sonnets/CXXXV.txt,4
# large sonnets/CXXXV.txt,4
# and sonnets/CXXXV.txt,4
# spacious sonnets/CXXXV.txt,4
# not sonnets/CXXXV.txt,5
# once sonnets/CXXXV.txt,5
# vouchsafe sonnets/CXXXV.txt,5
# to sonnets/CXXXV.txt,5
# hide sonnets/CXXXV.txt,5
# my sonnets/CXXXV.txt,5
# will sonnets/CXXXV.txt,5
# in sonnets/CXXXV.txt,5
# thine sonnets/CXXXV.txt,5
# shall sonnets/CXXXV.txt,6
# will sonnets/CXXXV.txt,6
# in sonnets/CXXXV.txt,6
# others sonnets/CXXXV.txt,6
# seem sonnets/CXXXV.txt,6
# right sonnets/CXXXV.txt,6
# gracious sonnets/CXXXV.txt,6
# and sonnets/CXXXV.txt,7
# in sonnets/CXXXV.txt,7
# my sonnets/CXXXV.txt,7
# will sonnets/CXXXV.txt,7
# no sonnets/CXXXV.txt,7
# fair sonnets/CXXXV.txt,7
# acceptance sonnets/CXXXV.txt,7
# shine sonnets/CXXXV.txt,7
# the sonnets/CXXXV.txt,8
# sea sonnets/CXXXV.txt,8
# all sonnets/CXXXV.txt,8
# water sonnets/CXXXV.txt,8
# yet sonnets/CXXXV.txt,8
# receives sonnets/CXXXV.txt,8
# rain sonnets/CXXXV.txt,8
# still sonnets/CXXXV.txt,8
# and sonnets/CXXXV.txt,9
# in sonnets/CXXXV.txt,9
# abundance sonnets/CXXXV.txt,9
# addeth sonnets/CXXXV.txt,9
# to sonnets/CXXXV.txt,9
# his sonnets/CXXXV.txt,9
# store sonnets/CXXXV.txt,9
# so sonnets/CXXXV.txt,10
# thou sonnets/CXXXV.txt,10
# being sonnets/CXXXV.txt,10
# rich sonnets/CXXXV.txt,10
# in sonnets/CXXXV.txt,10
# will sonnets/CXXXV.txt,10
# add sonnets/CXXXV.txt,10
# to sonnets/CXXXV.txt,10
# thy sonnets/CXXXV.txt,10
# will sonnets/CXXXV.txt,10
# one sonnets/CXXXV.txt,11
# will sonnets/CXXXV.txt,11
# of sonnets/CXXXV.txt,11
# mine sonnets/CXXXV.txt,11
# to sonnets/CXXXV.txt,11
# make sonnets/CXXXV.txt,11
# thy sonnets/CXXXV.txt,11
# large sonnets/CXXXV.txt,11
# will sonnets/CXXXV.txt,11
# more sonnets/CXXXV.txt,11
# let sonnets/CXXXV.txt,12
# no sonnets/CXXXV.txt,12
# unkind sonnets/CXXXV.txt,12
# no sonnets/CXXXV.txt,12
# fair sonnets/CXXXV.txt,12
# beseechers sonnets/CXXXV.txt,12
# kill sonnets/CXXXV.txt,12
# think sonnets/CXXXV.txt,13
# all sonnets/CXXXV.txt,13
# but sonnets/CXXXV.txt,13
# one sonnets/CXXXV.txt,13
# and sonnets/CXXXV.txt,13
# me sonnets/CXXXV.txt,13
# in sonnets/CXXXV.txt,13
# that sonnets/CXXXV.txt,13
# one sonnets/CXXXV.txt,13
# will sonnets/CXXXV.txt,13

# %%
indexdict = collections.defaultdict(list)

# loop over sonnets
for partial in partials:
    # loop over lines
    for entry in partial.split('\n'):
        # get word and location
        word, loc = entry.split(' ')

        # append to the location list for the word
        indexdict[word].append(loc)

# %%
indexdict['love']
# Out:
# ['sonnets/CXLVII.txt,0',
#  'sonnets/CXLVII.txt,4',
#  'sonnets/CXVIII.txt,8',
#  'sonnets/XIII.txt,0',
#  'sonnets/XIII.txt,12',
#  'sonnets/IX.txt,12',
#  'sonnets/CLIV.txt,13',
#  'sonnets/XXIII.txt,10',
#  'sonnets/XXIII.txt,12',
#  'sonnets/LXXXIX.txt,4',
#  'sonnets/LXXXIX.txt,13',
#  'sonnets/XXI.txt,8',
#  'sonnets/XXI.txt,9',
#  'sonnets/LXIV.txt,11',
#  'sonnets/XXXIV.txt,12',
#  'sonnets/CXL.txt,5',
#  'sonnets/CXL.txt,5',
#  'sonnets/XLVI.txt,13',
#  'sonnets/CLI.txt,0',
#  'sonnets/CLI.txt,1',
#  'sonnets/CLI.txt,7',
#  'sonnets/CLI.txt,13',
#  'sonnets/CLI.txt,13',
#  'sonnets/LXXXII.txt,8',
#  'sonnets/CXVI.txt,1',
#  'sonnets/CXVI.txt,1',
#  'sonnets/CXVI.txt,10',
#  'sonnets/LVII.txt,12',
#  'sonnets/LXXXVIII.txt,12',
#  'sonnets/XLVII.txt,3',
#  'sonnets/XLVII.txt,7',
#  'sonnets/XLVII.txt,8',
#  'sonnets/LXIII.txt,0',
#  'sonnets/CX.txt,7',
#  'sonnets/CX.txt,11',
#  'sonnets/LXXI.txt,5',
#  'sonnets/LXXI.txt,11',
#  'sonnets/XLIX.txt,2',
#  'sonnets/XLIX.txt,6',
#  'sonnets/XLIX.txt,13',
#  'sonnets/XXXI.txt,2',
#  'sonnets/XXXI.txt,5',
#  'sonnets/XXXI.txt,8',
#  'sonnets/CL.txt,8',
#  'sonnets/CL.txt,10',
#  'sonnets/CL.txt,12',
#  'sonnets/CXIX.txt,10',
#  'sonnets/CXXII.txt,9',
#  'sonnets/LXXX.txt,13',
#  'sonnets/CI.txt,2',
#  'sonnets/XLII.txt,3',
#  'sonnets/XLII.txt,5',
#  'sonnets/XLII.txt,5',
#  'sonnets/CXXXVIII.txt,0',
#  'sonnets/CXXXVIII.txt,11',
#  'sonnets/LXV.txt,13',
#  'sonnets/X.txt,0',
#  'sonnets/X.txt,9',
#  'sonnets/X.txt,12',
#  'sonnets/XV.txt,12',
#  'sonnets/CXII.txt,0',
#  'sonnets/LVI.txt,0',
#  'sonnets/LVI.txt,4',
#  'sonnets/LVI.txt,7',
#  'sonnets/LVI.txt,11',
#  'sonnets/XXXV.txt,11',
#  'sonnets/LXX.txt,6',
#  'sonnets/C.txt,12',
#  'sonnets/LI.txt,0',
#  'sonnets/LI.txt,9',
#  'sonnets/LI.txt,11',
#  'sonnets/LI.txt,11',
#  'sonnets/XL.txt,0',
#  'sonnets/XL.txt,2',
#  'sonnets/XL.txt,2',
#  'sonnets/XL.txt,2',
#  'sonnets/XL.txt,4',
#  'sonnets/XL.txt,4',
#  'sonnets/XL.txt,5',
#  'sonnets/XL.txt,10',
#  'sonnets/CII.txt,0',
#  'sonnets/CII.txt,1',
#  'sonnets/CII.txt,2',
#  'sonnets/CII.txt,4',
#  'sonnets/CLIII.txt,4',
#  'sonnets/XXVI.txt,0',
#  'sonnets/XXVI.txt,12',
#  'sonnets/XCVI.txt,12',
#  'sonnets/CXXIV.txt,0',
#  'sonnets/CXXIV.txt,2',
#  'sonnets/CXXXVII.txt,0',
#  'sonnets/XX.txt,13',
#  'sonnets/LXVI.txt,13',
#  'sonnets/XXXVI.txt,12',
#  'sonnets/CVII.txt,2',
#  'sonnets/CVII.txt,9',
#  'sonnets/LXI.txt,8',
#  'sonnets/LXI.txt,9',
#  'sonnets/LXI.txt,10',
#  'sonnets/XIX.txt,13',
#  'sonnets/CXXXVI.txt,3',
#  'sonnets/CXXXVI.txt,4',
#  'sonnets/CXXXVI.txt,12',
#  'sonnets/CXXXVI.txt,12',
#  'sonnets/CIX.txt,4',
#  'sonnets/XCIII.txt,2',
#  'sonnets/XCIII.txt,9',
#  'sonnets/CV.txt,0',
#  'sonnets/CV.txt,4',
#  'sonnets/LXXVI.txt,8',
#  'sonnets/LXXVI.txt,9',
#  'sonnets/LXXVI.txt,13',
#  'sonnets/CXLVIII.txt,0',
#  'sonnets/CXLVIII.txt,6',
#  'sonnets/CXLVIII.txt,12',
#  'sonnets/CXIV.txt,3',
#  'sonnets/CVIII.txt,3',
#  'sonnets/CVIII.txt,8',
#  'sonnets/CVIII.txt,12',
#  'sonnets/LXXXV.txt,10',
#  'sonnets/CXVII.txt,2',
#  'sonnets/CXVII.txt,13',
#  'sonnets/XCI.txt,8',
#  'sonnets/LXXIX.txt,4',
#  'sonnets/CXLIX.txt,0',
#  'sonnets/CXLIX.txt,12',
#  'sonnets/CLII.txt,1',
#  'sonnets/CLII.txt,3',
#  'sonnets/CLII.txt,9',
#  'sonnets/CXXXIX.txt,8',
#  'sonnets/CXXX.txt,8',
#  'sonnets/CXXX.txt,12',
#  'sonnets/CXXXI.txt,5',
#  'sonnets/XXXII.txt,6',
#  'sonnets/XXXII.txt,10',
#  'sonnets/XXXII.txt,13',
#  'sonnets/XXV.txt,12',
#  'sonnets/XXXIII.txt,12',
#  'sonnets/CXV.txt,1',
#  'sonnets/CXV.txt,9',
#  'sonnets/CXV.txt,12',
#  'sonnets/CXLI.txt,0',
#  'sonnets/XXII.txt,8',
#  'sonnets/XCII.txt,2',
#  'sonnets/XCII.txt,3',
#  'sonnets/XCII.txt,11',
#  'sonnets/XXXVII.txt,7',
#  'sonnets/LXXII.txt,1',
#  'sonnets/LXXII.txt,2',
#  'sonnets/LXXII.txt,8',
#  'sonnets/LXXII.txt,9',
#  'sonnets/LXXII.txt,13',
#  'sonnets/CXLII.txt,0',
#  'sonnets/CXLII.txt,6',
#  'sonnets/CXLII.txt,8',
#  'sonnets/XLV.txt,5',
#  'sonnets/CXXXII.txt,0',
#  'sonnets/XXXIX.txt,5',
#  'sonnets/XXXIX.txt,10',
#  'sonnets/LXXIII.txt,12',
#  'sonnets/LXXIII.txt,13',
#  'sonnets/XXIX.txt,12']

# %%
with open('index.txt', 'w') as outfile:
    # loop over words
    for word in sorted(indexdict.keys()):
        # make single space-separated string out of sorted locations
        locstring = ' '.join(sorted(indexdict[word]))

        # write out word + sorted-location string
        outfile.write(f'{word} {locstring}\n')

# %%
open('index.txt', 'r').readlines()[:10]
# Out:
# ['a sonnets/C.txt,10 sonnets/CI.txt,10 sonnets/CIII.txt,1 sonnets/CIII.txt,5 sonnets/CIV.txt,8 sonnets/CLII.txt,13 sonnets/CLIII.txt,1 sonnets/CLIII.txt,11 sonnets/CLIII.txt,3 sonnets/CLIII.txt,5 sonnets/CLIII.txt,6 sonnets/CLIII.txt,7 sonnets/CLIV.txt,10 sonnets/CLIV.txt,7 sonnets/CLIV.txt,8 sonnets/CV.txt,5 sonnets/CVI.txt,7 sonnets/CVII.txt,3 sonnets/CX.txt,1 sonnets/CX.txt,11 sonnets/CXI.txt,4 sonnets/CXI.txt,8 sonnets/CXIV.txt,6 sonnets/CXLI.txt,1 sonnets/CXLI.txt,10 sonnets/CXLIII.txt,0 sonnets/CXLIV.txt,2 sonnets/CXLIV.txt,3 sonnets/CXLIV.txt,6 sonnets/CXLV.txt,10 sonnets/CXLVI.txt,4 sonnets/CXLVII.txt,0 sonnets/CXV.txt,12 sonnets/CXVIII.txt,10 sonnets/CXVIII.txt,6 sonnets/CXX.txt,12 sonnets/CXX.txt,5 sonnets/CXX.txt,6 sonnets/CXXIII.txt,3 sonnets/CXXIX.txt,0 sonnets/CXXIX.txt,10 sonnets/CXXIX.txt,10 sonnets/CXXIX.txt,11 sonnets/CXXIX.txt,11 sonnets/CXXIX.txt,6 sonnets/CXXV.txt,12 sonnets/CXXVII.txt,11 sonnets/CXXVII.txt,3 sonnets/CXXX.txt,10 sonnets/CXXX.txt,9 sonnets/CXXXI.txt,9 sonnets/CXXXIII.txt,7 sonnets/CXXXIV.txt,10 sonnets/CXXXVI.txt,11 sonnets/CXXXVI.txt,7 sonnets/CXXXVII.txt,11 sonnets/CXXXVII.txt,8 sonnets/I.txt,6 sonnets/II.txt,3 sonnets/IV.txt,7 sonnets/IX.txt,0 sonnets/IX.txt,3 sonnets/L.txt,10 sonnets/LIV.txt,4 sonnets/LIX.txt,3 sonnets/LIX.txt,4 sonnets/LVI.txt,7 sonnets/LVII.txt,10 sonnets/LVII.txt,12 sonnets/LXIII.txt,8 sonnets/LXIV.txt,12 sonnets/LXV.txt,2 sonnets/LXV.txt,3 sonnets/LXVI.txt,1 sonnets/LXVIII.txt,12 sonnets/LXVIII.txt,3 sonnets/LXVIII.txt,6 sonnets/LXX.txt,3 sonnets/LXX.txt,7 sonnets/LXXIV.txt,10 sonnets/LXXIX.txt,5 sonnets/LXXV.txt,3 sonnets/LXXV.txt,9 sonnets/LXXVI.txt,5 sonnets/LXXVII.txt,11 sonnets/LXXVIII.txt,7 sonnets/LXXX.txt,1 sonnets/LXXX.txt,10 sonnets/LXXXI.txt,6 sonnets/LXXXII.txt,5 sonnets/LXXXIII.txt,11 sonnets/LXXXIII.txt,3 sonnets/LXXXIII.txt,6 sonnets/LXXXIV.txt,10 sonnets/LXXXIV.txt,12 sonnets/LXXXIX.txt,5 sonnets/LXXXVI.txt,5 sonnets/LXXXVII.txt,12 sonnets/LXXXVII.txt,13 sonnets/LXXXVIII.txt,5 sonnets/LXXXVIII.txt,8 sonnets/V.txt,9 sonnets/VII.txt,13 sonnets/XC.txt,5 sonnets/XC.txt,6 sonnets/XC.txt,6 sonnets/XC.txt,7 sonnets/XCI.txt,5 sonnets/XCII.txt,10 sonnets/XCII.txt,6 sonnets/XCIII.txt,1 sonnets/XCIX.txt,12 sonnets/XCIX.txt,9 sonnets/XCV.txt,1 sonnets/XCV.txt,6 sonnets/XCV.txt,8 sonnets/XCVI.txt,4 sonnets/XCVI.txt,9 sonnets/XCVII.txt,0 sonnets/XCVII.txt,12 sonnets/XCVIII.txt,2 sonnets/XIII.txt,13 sonnets/XIII.txt,8 sonnets/XL.txt,10 sonnets/XLI.txt,11 sonnets/XLI.txt,6 sonnets/XLII.txt,3 sonnets/XLVI.txt,0 sonnets/XLVI.txt,5 sonnets/XLVI.txt,9 sonnets/XLVII.txt,0 sonnets/XLVII.txt,2 sonnets/XLVII.txt,7 sonnets/XLVIII.txt,13 sonnets/XV.txt,1 sonnets/XVI.txt,0 sonnets/XVII.txt,10 sonnets/XVII.txt,2 sonnets/XVIII.txt,0 sonnets/XVIII.txt,3 sonnets/XX.txt,0 sonnets/XX.txt,2 sonnets/XX.txt,6 sonnets/XX.txt,8 sonnets/XXI.txt,1 sonnets/XXI.txt,4 sonnets/XXV.txt,7 sonnets/XXV.txt,9 sonnets/XXVII.txt,10 sonnets/XXVII.txt,2 sonnets/XXVII.txt,5 sonnets/XXX.txt,2 sonnets/XXX.txt,7 sonnets/XXXI.txt,4 sonnets/XXXII.txt,10 sonnets/XXXIII.txt,0 sonnets/XXXIV.txt,0 sonnets/XXXIV.txt,6 sonnets/XXXIX.txt,8 sonnets/XXXV.txt,10 sonnets/XXXVI.txt,5 sonnets/XXXVII.txt,0 sonnets/XXXVII.txt,11\n',
#  'abhor sonnets/CL.txt,10 sonnets/CL.txt,11\n',
#  'abide sonnets/XLV.txt,1 sonnets/XXVII.txt,4\n',
#  'able sonnets/LXXXV.txt,6\n',
#  'about sonnets/CXIII.txt,1\n',
#  'above sonnets/CX.txt,5 sonnets/CXXII.txt,2 sonnets/LXXXVI.txt,5 sonnets/XCI.txt,5\n',
#  'absence sonnets/CIX.txt,1 sonnets/LVII.txt,6 sonnets/LVIII.txt,5 sonnets/XCVII.txt,0 sonnets/XXXIX.txt,8\n',
#  'absent sonnets/LXXXIX.txt,8 sonnets/XCVIII.txt,0 sonnets/XLI.txt,1\n',
#  'abundance sonnets/CXXXV.txt,9 sonnets/I.txt,6 sonnets/XXIII.txt,3 sonnets/XXXVII.txt,10\n',
#  'abundant sonnets/XCVII.txt,8\n']

# %%
sorted(indexdict, key=lambda x: len(indexdict[x]), reverse=True)
# Out:
# ['and',
#  'the',
#  'to',
#  'of',
#  'my',
#  'i',
#  'in',
#  'that',
#  'thy',
#  'thou',
#  'with',
#  'for',
#  'is',
#  'not',
#  'but',
#  'me',
#  'a',
#  'thee',
#  'love',
#  'so',
#  'be',
#  'as',
#  'all',
#  'you',
#  'his',
#  'which',
#  'when',
#  'this',
#  'it',
#  'by',
#  'your',
#  'doth',
#  'do',
#  'from',
#  'on',
#  'or',
#  'no',
#  'have',
#  'then',
#  'what',
#  'are',
#  'if',
#  'will',
#  'more',
#  'mine',
#  'their',
#  'shall',
#  'sweet',
#  'eyes',
#  'they',
#  'time',
#  'beauty',
#  'nor',
#  'her',
#  'art',
#  'yet',
#  'heart',
#  'o',
#  'than',
#  'now',
#  'can',
#  'thine',
#  'should',
#  'hath',
#  'fair',
#  'one',
#  'make',
#  'he',
#  'where',
#  'still',
#  'how',
#  'eye',
#  'true',
#  'him',
#  'am',
#  'see',
#  'loves',
#  'like',
#  'she',
#  'those',
#  'though',
#  'being',
#  'every',
#  'some',
#  'were',
#  'such',
#  'own',
#  'who',
#  'was',
#  'dost',
#  'may',
#  'upon',
#  'myself',
#  'say',
#  'live',
#  'praise',
#  'most',
#  'give',
#  'world',
#  'let',
#  'did',
#  'at',
#  'might',
#  'ill',
#  'day',
#  'why',
#  'times',
#  'even',
#  'since',
#  'truth',
#  'show',
#  'life',
#  'new',
#  'thus',
#  'night',
#  'best',
#  'look',
#  'well',
#  'old',
#  'would',
#  'dear',
#  'thyself',
#  'must',
#  'these',
#  'part',
#  'whose',
#  'made',
#  'false',
#  'face',
#  'worth',
#  'better',
#  'nothing',
#  'alone',
#  'thoughts',
#  'thought',
#  'our',
#  'there',
#  'much',
#  'days',
#  'against',
#  'beautys',
#  'too',
#  'away',
#  'them',
#  'hast',
#  'know',
#  'had',
#  'an',
#  'hand',
#  'name',
#  'therefore',
#  'both',
#  'sight',
#  'find',
#  'dead',
#  'muse',
#  'other',
#  'mind',
#  'out',
#  'hate',
#  'far',
#  'others',
#  'think',
#  'death',
#  'we',
#  'verse',
#  'poor',
#  'before',
#  'up',
#  'men',
#  'age',
#  'each',
#  'tell',
#  'good',
#  'come',
#  'youth',
#  'never',
#  'wilt',
#  'state',
#  'things',
#  'till',
#  'gentle',
#  'friend',
#  'black',
#  'use',
#  'proud',
#  'hold',
#  'none',
#  'many',
#  'whilst',
#  'prove',
#  'take',
#  'heaven',
#  'lie',
#  'making',
#  'seem',
#  'bear',
#  'die',
#  'thing',
#  'woe',
#  'whom',
#  'first',
#  'hours',
#  'change',
#  'summers',
#  'lies',
#  'full',
#  'mayst',
#  'looks',
#  'rich',
#  'desire',
#  'bright',
#  'kind',
#  'form',
#  'happy',
#  'grace',
#  'yourself',
#  'shalt',
#  'long',
#  'hearts',
#  'tongue',
#  'pleasure',
#  'sun',
#  'tis',
#  'ever',
#  'earth',
#  'any',
#  'seen',
#  'knows',
#  'within',
#  'pride',
#  'once',
#  'right',
#  'pen',
#  'end',
#  'again',
#  'after',
#  'place',
#  'shame',
#  'nature',
#  'great',
#  'could',
#  'deeds',
#  'glass',
#  'self',
#  'write',
#  'soul',
#  'leave',
#  'words',
#  'spirit',
#  'call',
#  'another',
#  'store',
#  'past',
#  'found',
#  'stay',
#  'decay',
#  'keep',
#  'lives',
#  'fire',
#  'cannot',
#  'lose',
#  'power',
#  'back',
#  'strong',
#  'treasure',
#  'beauteous',
#  'two',
#  'makes',
#  'although',
#  'loving',
#  'gone',
#  'hell',
#  'faults',
#  'thence',
#  'view',
#  'fear',
#  'sin',
#  'blood',
#  'mistress',
#  'lovely',
#  'disgrace',
#  'gives',
#  'speak',
#  'without',
#  'lest',
#  'child',
#  'summer',
#  'skill',
#  'sake',
#  'pity',
#  'flowers',
#  'loss',
#  'cruel',
#  'grow',
#  'brow',
#  'stand',
#  'bring',
#  'save',
#  'glory',
#  'joy',
#  'lines',
#  'delight',
#  'memory',
#  'leaves',
#  'shadow',
#  'blessed',
#  'living',
#  'sing',
#  'born',
#  'honour',
#  'cold',
#  'ah',
#  'waste',
#  'itself',
#  'steal',
#  'roses',
#  'bad',
#  'put',
#  'breast',
#  'foul',
#  'set',
#  'slave',
#  'straight',
#  'canst',
#  'whether',
#  'lips',
#  'forth',
#  'outward',
#  'wide',
#  'deep',
#  'excuse',
#  'very',
#  'less',
#  'tender',
#  'parts',
#  'sad',
#  'fresh',
#  'three',
#  'ten',
#  'swear',
#  'worst',
#  'white',
#  'breath',
#  'virtue',
#  'behold',
#  'enough',
#  'longer',
#  'reason',
#  'care',
#  'sick',
#  'ere',
#  'light',
#  'through',
#  'heavy',
#  'under',
#  'taught',
#  'dumb',
#  'deaths',
#  'eternal',
#  'painting',
#  'seeing',
#  'rose',
#  'wealth',
#  'strength',
#  'writ',
#  'hear',
#  'wit',
#  'sweets',
#  'natures',
#  'else',
#  'judgment',
#  'strange',
#  'dwell',
#  'wrong',
#  'been',
#  'book',
#  'same',
#  'themselves',
#  'heavens',
#  'only',
#  'fortune',
#  'gainst',
#  'compare',
#  'sometime',
#  'fears',
#  'way',
#  'spent',
#  'hence',
#  'go',
#  'war',
#  'due',
#  'hope',
#  'head',
#  'blind',
#  'despite',
#  'unless',
#  'music',
#  'lovest',
#  'shouldst',
#  'precious',
#  'oer',
#  'while',
#  'shows',
#  'rhyme',
#  'argument',
#  'return',
#  'having',
#  'dull',
#  'rest',
#  'wish',
#  'large',
#  'hide',
#  'gracious',
#  'water',
#  'kill',
#  'left',
#  'cure',
#  'grew',
#  'rank',
#  'fell',
#  'oft',
#  'graces',
#  'yours',
#  'winters',
#  'barren',
#  'rage',
#  'shape',
#  'spend',
#  'cheek',
#  'hue',
#  'side',
#  'brand',
#  'fairest',
#  'took',
#  'trust',
#  'speaking',
#  'read',
#  'says',
#  'gift',
#  'lend',
#  'painted',
#  'spring',
#  'year',
#  'absence',
#  'beloved',
#  'invention',
#  'antique',
#  'done',
#  'worse',
#  'flower',
#  'base',
#  'sweetest',
#  'keeps',
#  'purpose',
#  'wherein',
#  'saw',
#  'doom',
#  'chide',
#  'ornament',
#  'truly',
#  'buried',
#  'mortal',
#  'man',
#  'grief',
#  'sorrow',
#  'tears',
#  'least',
#  'fast',
#  'pain',
#  'near',
#  'mad',
#  'angel',
#  'subject',
#  'need',
#  'scope',
#  'loved',
#  'boast',
#  'tomb',
#  'needs',
#  'merit',
#  'friends',
#  'moan',
#  'date',
#  'swift',
#  'holds',
#  'play',
#  'wrinkles',
#  'green',
#  'gave',
#  'into',
#  'motion',
#  'stars',
#  'worthy',
#  'calls',
#  'stoln',
#  'worlds',
#  'brain',
#  'golden',
#  'winter',
#  'spite',
#  'mens',
#  'tongues',
#  'faith',
#  'quite',
#  'birth',
#  'shine',
#  'sea',
#  'abundance',
#  'add',
#  'please',
#  'frame',
#  'assured',
#  'sleep',
#  'shadows',
#  'shade',
#  'high',
#  'given',
#  'works',
#  'rude',
#  'here',
#  'lease',
#  'single',
#  'behind',
#  'unused',
#  'wherefore',
#  'seek',
#  'laid',
#  'heat',
#  'bath',
#  'canker',
#  'story',
#  'report',
#  'turn',
#  'knife',
#  'holy',
#  'lack',
#  'knowst',
#  'knowing',
#  'substance',
#  'appear',
#  'account',
#  'leisure',
#  'crime',
#  'blame',
#  'second',
#  'former',
#  'image',
#  'slow',
#  'smell',
#  'weeds',
#  'hour',
#  'grown',
#  'lovers',
#  'sovereign',
#  'pluck',
#  'wretched',
#  'minutes',
#  'body',
#  'want',
#  'said',
#  'public',
#  'rehearse',
#  'rare',
#  'air',
#  'believe',
#  'brass',
#  'gain',
#  'win',
#  'clouds',
#  'break',
#  'wound',
#  'lends',
#  'short',
#  'free',
#  'comfort',
#  'lost',
#  'tonguetied',
#  'inward',
#  'sum',
#  'count',
#  'evil',
#  'young',
#  'worms',
#  'grant',
#  'touches',
#  'cheeks',
#  'weary',
#  'toil',
#  'tired',
#  'souls',
#  'jewel',
#  'minds',
#  'mark',
#  'told',
#  'present',
#  'scythe',
#  'poets',
#  'sense',
#  'song',
#  'dare',
#  'forsworn',
#  'down',
#  'buds',
#  'catch',
#  'babe',
#  'numbers',
#  'beauties',
#  'above',
#  'forgot',
#  'methinks',
#  'removed',
#  'just',
#  'increase',
#  'errors',
#  'grows',
#  'prime',
#  'groan',
#  'help',
#  'lays',
#  'taste',
#  'common',
#  'praises',
#  'thief',
#  'bare',
#  'respect',
#  'lived',
#  'oaths',
#  'red',
#  'receives',
#  'rain',
#  'unkind',
#  'feeding',
#  'appetite',
#  'kept',
#  'approve',
#  'evermore',
#  'expressd',
#  'sworn',
#  'dark',
#  'brought',
#  'clear',
#  'looking',
#  'got',
#  'mend',
#  'style',
#  'decease',
#  'fall',
#  'father',
#  'son',
#  'weep',
#  'murderous',
#  'infection',
#  'advantage',
#  'came',
#  'maiden',
#  'general',
#  'hot',
#  'growing',
#  'burden',
#  'sins',
#  'cover',
#  'blot',
#  'edge',
#  'heir',
#  'bastard',
#  'mourn',
#  'bonds',
#  'cause',
#  'gavest',
#  'home',
#  'flatter',
#  'matter',
#  'tend',
#  'constant',
#  'forbid',
#  'control',
#  'injury',
#  'didst',
#  'fault',
#  'reasons',
#  'half',
#  'acquaintance',
#  'absent',
#  'haply',
#  'neer',
#  'amiss',
#  'record',
#  'five',
#  'character',
#  'wonder',
#  'sure',
#  'stone',
#  'husband',
#  'expense',
#  'basest',
#  'weed',
#  'boy',
#  'therein',
#  'audit',
#  'bosoms',
#  'windows',
#  'turns',
#  'drawn',
#  'cunning',
#  'draw',
#  'used',
#  'anew',
#  'greet',
#  'means',
#  'manners',
#  'almost',
#  'moon',
#  'mothers',
#  'cost',
#  'ocean',
#  'shore',
#  'main',
#  'bears',
#  'cross',
#  'eternity',
#  'favour',
#  'simple',
#  'stands',
#  'woman',
#  'womans',
#  'abuse',
#  'teach',
#  'despair',
#  'conquest',
#  'plea',
#  'answer',
#  'soon',
#  'suspect',
#  'anothers',
#  'conscience',
#  'bodys',
#  'triumph',
#  'prize',
#  'contented',
#  'line',
#  'wert',
#  'knowledge',
#  'chest',
#  'blest',
#  'haste',
#  'work',
#  'lo',
#  'star',
#  'height',
#  'taken',
#  'fool',
#  'brief',
#  'proved',
#  'silence',
#  'steel',
#  'tyrant',
#  'rememberd',
#  'receivest',
#  'ear',
#  'confounds',
#  'seeming',
#  'nought',
#  'fight',
#  'virtuous',
#  'losing',
#  'pay',
#  'shake',
#  'complexion',
#  'course',
#  'fade',
#  'flies',
#  'kiss',
#  'picture',
#  'farther',
#  'filld',
#  'number',
#  'heavenly',
#  'ages',
#  'proof',
#  'confined',
#  'vile',
#  'thinking',
#  'mock',
#  'frown',
#  'pass',
#  'desert',
#  'lawful',
#  'seasons',
#  'april',
#  'pace',
#  'princes',
#  'outlive',
#  'quick',
#  'burn',
#  'posterity',
#  'wear',
#  'wouldst',
#  'vulgar',
#  'grave',
#  'whence',
#  'flame',
#  'eat',
#  'distilld',
#  'fairer',
#  'greater',
#  'thrice',
#  'remain',
#  'repair',
#  'selflove',
#  'sail',
#  'speed',
#  'bloody',
#  'fame',
#  'ride',
#  'colour',
#  'because',
#  'birds',
#  'odour',
#  'seemd',
#  'fortunes',
#  'happier',
#  'twain',
#  'flattery',
#  'action',
#  'alack',
#  'foot',
#  'whereon',
#  'brave',
#  'conceit',
#  'takes',
#  'perjured',
#  'despised',
#  'fill',
#  'today',
#  'tomorrow',
#  'daily',
#  'thorns',
#  'stain',
#  'wood',
#  'among',
#  'foes',
#  'growth',
#  'ground',
#  'pine',
#  'bearing',
#  'duty',
#  'witness',
#  'whereto',
#  'plague',
#  'womens',
#  'effect',
#  'fingers',
#  'elsewhere',
#  'blunt',
#  'sinful',
#  'crownd',
#  'constancy',
#  'whats',
#  'dearest',
#  'thousand',
#  'west',
#  'hang',
#  'vex',
#  'addition',
#  'vouchsafe',
#  'fever',
#  'physic',
#  'vainly',
#  'keen',
#  'compounds',
#  'palate',
#  'urge',
#  'maladies',
#  'unseen',
#  'shun',
#  'sweetness',
#  'bitter',
#  'diseased',
#  'policy',
#  'healthful',
#  'goodness',
#  'learn',
#  'wink',
#  'unrespected',
#  'dreams',
#  'clearer',
#  'shines',
#  'sightless',
#  'nights',
#  'ignorance',
#  'added',
#  'double',
#  'majesty',
#  'influence',
#  'arts',
#  'learning',
#  'coming',
#  'prepare',
#  'issue',
#  'husbandry',
#  'wail',
#  'widow',
#  'bosom',
#  'himself',
#  'commits',
#  'presence',
#  'lively',
#  'veins',
#  'stores',
#  'last',
#  'little',
#  'asleep',
#  'perpetual',
#  'remedy',
#  'stage',
#  'besides',
#  'fierce',
#  'replete',
#  'forget',
#  'perfect',
#  'plead',
#  'silent',
#  'belongs',
#  'fine',
#  'tells',
#  'lascivious',
#  'comments',
#  'sport',
#  'mansion',
#  'privilege',
#  'bore',
#  'borrowd',
#  'profaned',
#  'mourners',
#  'creation',
#  'esteem',
#  'becoming',
#  'possessing',
#  'charter',
#  'riches',
#  'wanting',
#  'comes',
#  'dream',
#  'king',
#  'whereof',
#  'counterfeit',
#  'bounty',
#  'god',
#  'vassal',
#  'bound',
#  'suffer',
#  'imprisond',
#  'liberty',
#  'patience',
#  'bide',
#  'cheque',
#  'belong',
#  'wait',
#  'forsake',
#  'comment',
#  'offence',
#  'defence',
#  'desired',
#  'walks',
#  'vow',
#  'wits',
#  'subjects',
#  'moving',
#  'temptation',
#  'lords',
#  'owners',
#  'faces',
#  'excellence',
#  'meet',
#  'render',
#  'painter',
#  'held',
#  'delights',
#  'gaze',
#  'sound',
#  'giving',
#  'alterd',
#  'follow',
#  'fiend',
#  'guilty',
#  'goddess',
#  'willing',
#  'drink',
#  'potions',
#  'bitterness',
#  'ye',
#  'huge',
#  'gold',
#  'fixd',
#  'outworn',
#  'lofty',
#  'hungry',
#  'travel',
#  'rotten',
#  ...]

# %%
[len(indexdict[word]) for word in ['love','sweet','eyes']]
# Out:
# [162, 55, 55]
